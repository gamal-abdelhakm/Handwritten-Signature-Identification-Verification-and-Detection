# %%
import os
import numpy as np
import pandas as pd
import cv2

# %%
img_path = 'TrainImages/'
for img in os.listdir(img_path):
    my_img = cv2.imread(img_path+d[0])
    print(my_img.shape)
# Out:
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# (1000, 1000, 3)
# ...

# %%
source_lable_path = 'TrainGroundTruth/'
destination_lable_path = 'labels/'
img_w = 1000
img_h = 1000
    
for lable in os.listdir(source_lable_path):
    with open(source_lable_path+lable, "r") as txt_file:
        xmin,ymin,xmax,ymax = [int(i) for i in txt_file.readlines()[0][:-1].split(',')]
        cat = 0
        x_center = (xmin + xmax)/2
        y_center = (ymin + ymax)/2
        x_center /= img_w
        y_center /= img_h
        w = xmax - xmin
        h = ymax - ymin
        with open(destination_lable_path+lable, 'w+') as f:
            f.write(f'{cat},{x_center},{y_center},{w},{h}\n')
